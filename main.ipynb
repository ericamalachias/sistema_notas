# %%
print("Teste")
# Out:
# Teste

# %%
from cadastrar import cadastro
from media import media
from verificar import media_aluno

# %%
nome, n1, n2 = cadastro()

media_calculada = media(n1, n2)

situacao = media_aluno()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 5
#       1 nome, n1, n2 = cadastro()
#       3 media_calculada = media(n1, n2)
# ----> 5 situacao = media_aluno()
#
# TypeError: media_aluno() missing 1 required positional argument: 'media'
